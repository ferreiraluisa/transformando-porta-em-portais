# %%
from google.colab import drive

drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# !ls '/content/gdrive/My Drive/Trabalho Final - INF420 492/TRAINAMENTO YOLO'
# Out:
#  config.yaml   data   runs  'runs 97.2 model large'   YOLOv8

# %%
DATA_DIR = '/content/gdrive/My Drive/Trabalho Final - INF420 492/TRAINAMENTO YOLO/data'

# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 625.9/625.9 kB 22.6 MB/s eta 0:00:00
# ...

# %% [markdown]
# #1. Train

# %%
import os

from ultralytics import YOLO

model = YOLO('yolov8l-seg.pt')  # load a pretrained model (recommended for training)

model.train(data='/content/gdrive/My Drive/Trabalho Final - INF420 492/TRAINAMENTO YOLO/config.yaml', epochs=60, imgsz=640)
# Out:
# ...
# 100%|██████████| 88.1M/88.1M [00:02<00:00, 42.9MB/s]
# Ultralytics YOLOv8.0.128 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# !scp -r /content/runs '/content/gdrive/My Drive/Trabalho Final - INF420 492/runs'

# %% [markdown]
# #2. Predict

# %%
# !yolo predict model='/content/gdrive/MyDrive/Trabalho Final - INF 492/best-ml.pt' source='door_image.jpg'
